# %%
from stable_baselines3 import DQN, A2C
from stable_baselines3.common.env_util import make_atari_env,is_wrapped 
from stable_baselines3.common.vec_env import VecFrameStack, VecTransposeImage
from stable_baselines3.common.monitor import Monitor

# %%
env = make_atari_env('BreakoutNoFrameskip-v4',n_envs=4)

# %%
env = VecFrameStack(env,n_stack=4)

# %%
model =A2C('CnnPolicy',env,verbose=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=int(1e7))
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 816      |
# |    ep_rew_mean        | 1.78     |
# | time/                 |          |
# |    fps                | 149      |
# |    iterations         | 100      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.598    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.00172 |
# |    value_loss         | 2.74e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 785      |
# |    ep_rew_mean        | 1.57     |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 200      |
# |    time_elapsed       | 21       |
# ...

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 obs = env.reset()
#       2 while True:
# ----> 3     action, _states = model.predict(obs)
#       4     obs, rewards, dones, info = env.step(action)
#       5     env.render()
#
# File ~\anaconda3\envs\ai\lib\site-packages\stable_baselines3\common\base_class.py:579, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     559 def predict(
#     560     self,
#     561     observation: np.ndarray,
#    (...)
#     564     deterministic: bool = False,
#     565 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     566     """
#     567     Get the policy action from an observation (and optional hidden state).
#     568     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
# ...

# %%
env.close()

# %%
model.save(r'C:\Users\niels\OneDrive\Probabilistic Programming 2022\breakout_trained')

# %%
model = A2C.load(r'C:\Users\niels\OneDrive\Probabilistic Programming 2022\breakout_trained')
